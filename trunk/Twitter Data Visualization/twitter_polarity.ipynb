# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('leicester_city_twitter_data_5k.csv')
#df=pd.read_csv('leicester_city_twitter_data_10k.csv')
#df=pd.read_csv('leicester_city_twitter_data_20k.csv')
df.head()
# Out:
#    Unnamed: 0                  Date_time      Tweet_id  \
# 0           0  2023-02-23 21:28:19+00:00  1.628870e+18
# 1           1  2023-02-23 21:10:12+00:00  1.628860e+18
# 2           2  2023-02-23 20:50:39+00:00  1.628860e+18
# 3           3  2023-02-23 16:41:13+00:00  1.628800e+18
# 4           4  2023-02-23 16:39:50+00:00  1.628800e+18
#
#                                                 Text        User_name
# 0  @Leicester_News Wasted £600k on this, not to m...       Funkyrob0t
# 1  @rideonleicester How much has leicester city c...       Funkyrob0t
# 2  Another day, another completed SuDS project in...   WildscapesCoop
# 3  This Council recognises Samworth Brother’s par...  Union4Samworths
# 4  Incredible story from @HRichardsonLDR. Leicest...     CoreyBJourno

# %%
df.drop(['Unnamed: 0','Date_time','Tweet_id','User_name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                 Text
# 0  @Leicester_News Wasted £600k on this, not to m...
# 1  @rideonleicester How much has leicester city c...
# 2  Another day, another completed SuDS project in...
# 3  This Council recognises Samworth Brother’s par...
# 4  Incredible story from @HRichardsonLDR. Leicest...

# %%
# !pip3 install --upgrade vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)

# %%
import nltk
nltk.download(['stopwords'])#(['punkt','stopwords'])
from nltk.corpus import stopwords
stopwords = stopwords.words('english')

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.isnull().sum()
# Out:
# Text    0
# dtype: int64

# %%
df['tweet_cleaned'] = df['Text'].apply(lambda x: ' '.join([item for item in x.split() if item not in stopwords]))

# %%
df.sample(6)
# Out:
#                                                    Text  \
# 3926  @JonAshworth I'm one of your constituents and ...
# 4017  @smiffy9471 @Marisol04326417 Why didn’t the Co...
# 3470  Leicester city council: No fines for parents w...
# 1966  @LaraOyedele Reminiscent of Leicester City Cou...
# 3059  Project Coordinator – CURE Smoking Cessation\n...
# 1423  We're really proud to support Leicester City C...
#
#                                           tweet_cleaned
# 3926  @JonAshworth I'm one constituents I know alway...
# 4017  @smiffy9471 @Marisol04326417 Why didn’t Counci...
# 3470  Leicester city council: No fines parents conce...
# 1966  @LaraOyedele Reminiscent Leicester City Counci...
# 3059  Project Coordinator – CURE Smoking Cessation L...
# 1423  We're really proud support Leicester City Coun...

# %%
df['Sentiment_score'] = df['tweet_cleaned'].apply(lambda x: analyzer.polarity_scores(x)['compound'])

# %%
df.head()
# Out:
#                                                 Text  \
# 0  @Leicester_News Wasted £600k on this, not to m...
# 1  @rideonleicester How much has leicester city c...
# 2  Another day, another completed SuDS project in...
# 3  This Council recognises Samworth Brother’s par...
# 4  Incredible story from @HRichardsonLDR. Leicest...
#
#                                        tweet_cleaned  Sentiment_score
# 0  @Leicester_News Wasted £600k this, mention con...          -0.7964
# 1  @rideonleicester How much leicester city counc...          -0.5411
# 2  Another day, another completed SuDS project Le...           0.2960
# 3  This Council recognises Samworth Brother’s par...          -0.5859
# 4  Incredible story @HRichardsonLDR. Leicester Ci...           0.0000

# %%
df.sample(5)
# Out:
#                                                    Text  \
# 161   Great Moment of pride for the\nModel state 🔥\n...
# 1533  •Dumfries &amp; Galloway\n•Eilean Siar\n•Gates...
# 1705  .@LCFC has submitted its hybrid planning appli...
# 1275  The city council is calling on Leicester resid...
# 1887  How amazing is this?! The snakes and ladders a...
#
#                                           tweet_cleaned  Sentiment_score
# 161   Great Moment pride Model state 🔥 A signboard L...           0.4588
# 1533  •Dumfries &amp; Galloway •Eilean Siar •Gateshe...           0.0000
# 1705  .@LCFC submitted hybrid planning application L...           0.0000
# 1275  The city council calling Leicester residents s...           0.5859
# 1887  How amazing this?! The snakes ladders artwork ...           0.8820

# %%
def sentiment_class(sent_score):
  if sent_score>=0.05:
    sent_class=int(1)
  elif -0.05<sent_score<0.05:
    sent_class=int(0)
  else:
    sent_class=int(-1)
  
  return(sent_class)

# %%
df['Sentiment_class']= df['Sentiment_score'].apply(sentiment_class)

# %%
df.head()
# Out:
#                                                 Text  \
# 0  @Leicester_News Wasted £600k on this, not to m...
# 1  @rideonleicester How much has leicester city c...
# 2  Another day, another completed SuDS project in...
# 3  This Council recognises Samworth Brother’s par...
# 4  Incredible story from @HRichardsonLDR. Leicest...
#
#                                        tweet_cleaned  Sentiment_score  \
# 0  @Leicester_News Wasted £600k this, mention con...          -0.7964
# 1  @rideonleicester How much leicester city counc...          -0.5411
# 2  Another day, another completed SuDS project Le...           0.2960
# 3  This Council recognises Samworth Brother’s par...          -0.5859
# 4  Incredible story @HRichardsonLDR. Leicester Ci...           0.0000
#
#    Sentiment_class
# 0               -1
# 1               -1
# 2                1
# 3               -1
# 4                0

# %%
df.sample(6)
# Out:
#                                                    Text  \
# 4744  Great session with my 2 new clients Amy and Ki...
# 676   More than £8m generated for Leicester City Cou...
# 471   @nigel73200304 Big up the Coalville United. Th...
# 1756  @Leicester_News https://t.co/nG3GuEh2Gm\n\nWor...
# 1971  @GBNEWS I never knew Leicester City Council ma...
# 497   @leicslive The building and relocation of mark...
#
#                                           tweet_cleaned  Sentiment_score  \
# 4744  Great session 2 new clients Amy Kieron. Both s...           0.7906
# 676   More £8m generated Leicester City Council last...           0.0000
# 471   @nigel73200304 Big Coalville United. They woul...           0.4215
# 1756  @Leicester_News https://t.co/nG3GuEh2Gm Worth ...           0.0772
# 1971  @GBNEWS I never knew Leicester City Council ma...           0.0000
# 497   @leicslive The building relocation market kill...          -0.6908
#
#       Sentiment_class
# 4744                1
# 676                 0
# 471                 1
# 1756                1
# 1971                0
# 497                -1
